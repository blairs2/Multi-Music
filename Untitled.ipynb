# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
x = [1,2,4,8,16]
y = [1.4123,0.7612, 0.4470, 0.3464,0.2591 ]
plt.plot(x,y)
plt.xlabel("front/back end pipeline widths", size=15)
plt.ylabel("CPI", size = 15)
plt.title("pipeline width vs CPI", size = 15)
# Out:
# Text(0.5, 1.0, 'pipeline width vs CPI')

# %%
command = './sim-outorder -redir:prog anagram.progout -redir:sim anagram.simout -fetch:ifqsize {width} -decode:width {width} -issue:width {width} -res:ialu {width} -commit:width {width} -ruu:size 256 -lsq:size 128 tests/bin.little/anagram tests/inputs/words < tests/inputs/input.txt'

# %%
command.format(width=16)
# Out:
# './sim-outorder -redir:prog anagram.progout -redir:sim anagram.simout -fetch:ifqsize 16 -decode:width 16 -issue:width 16 -res:ialu 16 -commit:width 16 -ruu:size 256 -lsq:size 128 tests/bin.little/anagram tests/inputs/words < tests/inputs/input.txt'
